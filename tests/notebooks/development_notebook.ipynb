# %%
import pandas as pd
from pprint import pprint

import schtools

# %%
config = schtools.load_config_file()
pprint(config.keys())
# Out:
# dict_keys(['cloud', 'credentials', 'datasets'])

# %%
db = schtools.SCHToolsDatasets(config)

# %%
db.sch.head()
# Out:
#   Data da Homologação Número de Homologação              Nome do Solicitante  \
# 0          2025-04-03          041141303428  CommScope Cabos do Brasil Ltda.
# 1          2025-04-03          041141303428  CommScope Cabos do Brasil Ltda.
# 2          2015-01-23          044571407864               SouthPartner Ltda.
# 3          2015-01-23          044571407864               SouthPartner Ltda.
# 4          2017-09-21          037411102482  EXTREME NETWORKS DO BRASIL LTDA
#
#   CNPJ do Solicitante Certificado de Conformidade Técnica  \
# 0      03759340000601                        NCC 10296/13
# 1      03759340000601                        NCC 10296/13
# 2      04296807000174                        NCC 11559/14
# 3      04296807000174                        NCC 11559/14
# 4      69314862000195                         NCC 8067/11
#
#   Data do Certificado de Conformidade Técnica Data de Validade do Certificado  \
# ...

# %%
db.annotation.head()
# Out:
#                                      ID             DataHora      Computador  \
# 0  001f8c9b-c83f-488c-8bd4-fe92909a51ec  08/08/2024 11:31:59    ES6927559DTL
# 1  00225394-f4a7-4e96-8c33-d84dafefa1ac  06/10/2024 11:30:28    ES6927559DTL
# 2  002562da-097d-4f53-ae34-6ae6f92e9b48  24/09/2024 11:33:24    ES6927559DTL
# 3  003c2c5c-7823-41b8-978b-85c3f859d7cf  16/11/2024 15:00:42  WIFIPRTITSIN09
# 4  004631d8-85b5-4dad-b6de-5a7c8bd29659  30/10/2024 05:00:22  WIFIPRTITSIN09
#
#                 Usuário     Homologação   Atributo  \
# 0         maxwelfreitas  03685-11-05967  WordCloud
# 1         maxwelfreitas  15152-21-13346  WordCloud
# 2         maxwelfreitas  00183-04-02137  WordCloud
# 3  admin.fiprtiwi009.s1  16422-21-06146  WordCloud
# 4  admin.fiprtiwi009.s1  07709-23-12298  WordCloud
#
#                                                Valor  Situação  \
# 0  {"metaData": {"Version": 1, "Source": "BING", ...         0
# 1  {"metaData": {"Version": 1, "Source": "GOOGLE"...         0
# ...

# %%
# EXEMPLO DE BUSCA NO GOOGLE
# [212722316177 OR 21272-23-16177]
